# %%
# CNN

# %%
# plt.plot(x_ticker, oS_adol_200_CNN_valid_loss_ppl, label = "valid")
plt.plot(x_ticker2, oS_adol_200_CNN_testloss_cbt_ppl, label = "cbt")
plt.plot(x_ticker2, oS_adol_200_CNN_testloss_adult_ppl, label = "adult")

plt.title("Loss in training - adol sws vocab 200 CNN")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %%
plt.plot(x_ticker2, oS_adol_200_CNN_valid_loss_ppl, label = "training validation", color = 'g')


plt.title("Loss in training - adol sws vocab 200 CNN")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %% [markdown]
# Both testing loss for adult and cbt increases during training, even the training losses decreases

# %%
plt.plot(x_ticker2, oS_adol_10000_CNN_testloss_cbt_ppl, label = "cbt")
plt.plot(x_ticker2, oS_adol_10000_CNN_testloss_adult_ppl, label = "adult")


plt.title("Loss in training - adol sws vocab 10000 CNN")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %%
plt.plot(x_ticker2, oS_adol_10000_CNN_valid_loss_ppl, label = "training validation", color = 'g')


plt.title("Loss in training - adol sws vocab 10000 CNN")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %% [markdown]
# Same result for CNN when vocab size increased to 10000

# %%
# LSTM

# %%
plt.plot(x_ticker2, oS_adol_200_LSTM_testloss_cbt_ppl, label = "cbt")
plt.plot(x_ticker2, oS_adol_200_LSTM_testloss_adult_ppl, label = "adult")

plt.title("Loss in training - adol sws vocab 200 LSTM")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %%
plt.plot(x_ticker2, oS_adol_200_LSTM_valid_loss_ppl, label = "validation", color='g')


plt.title("Loss in training - adol sws vocab 200 LSTM")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %%
plt.plot(x_ticker2, oS_adol_10000_LSTM_testloss_cbt_ppl, label = "cbt")
plt.plot(x_ticker2, oS_adol_10000_LSTM_testloss_adult_ppl, label = "adult")


plt.title("Loss in training - adol sws vocab 10000 LSTM")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()

# %%
plt.plot(x_ticker2, oS_adol_10000_LSTM_valid_loss_ppl, label = "validation", color='g')


plt.title("Loss in training - adol sws vocab 10000 LSTM")
plt.xlabel('epoch')
plt.ylabel('PPL')
plt.legend()
plt.xticks(x_ticker2, rotation = -45)
plt.show()
